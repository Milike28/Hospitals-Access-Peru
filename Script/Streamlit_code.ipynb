# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (1.49.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: packaging<26,>=20 in c:\users\asus\appdata\roaming\python\python313\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.32.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\asus\appdata\roaming\python\python313\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.5.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python313\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install streamlit pandas geopandas folium matplotlib numpy shapely
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/85/9e/146cdef515ad07e56c3aa942d087562498592d441aa3bae845ef0cd8fca3/streamlit-1.49.1-py3-none-any.whl.metadata
#   Downloading streamlit-1.49.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pandas in c:\users\asus\appdata\roaming\python\python311\site-packages (2.3.2)
# Requirement already satisfied: geopandas in c:\users\asus\appdata\roaming\python\python311\site-packages (1.1.1)
# Requirement already satisfied: folium in c:\users\asus\appdata\roaming\python\python311\site-packages (0.20.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda31\lib\site-packages (3.7.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda31\lib\site-packages (1.24.3)
# Requirement already satisfied: shapely in c:\users\asus\appdata\roaming\python\python311\site-packages (2.1.1)
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0 (from streamlit)
#   Obtaining dependency information for altair!=5.4.0,!=5.4.1,<6,>=4.0 from https://files.pythonhosted.org/packages/aa/f3/0b6ced594e51cc95d8c1fc1640d3623770d01e4969d29c0bd09945fafefa/altair-5.5.0-py3-none-any.whl.metadata
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Obtaining dependency information for blinker<2,>=1.5.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Obtaining dependency information for cachetools<7,>=4.0 from https://files.pythonhosted.org/packages/6c/56/3124f61d37a7a4e7cc96afc5492c78ba0cb551151e530b54669ddd1436ef/cachetools-6.2.0-py3-none-any.whl.metadata
#   Downloading cachetools-6.2.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: packaging<26,>=20 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (23.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (9.4.0)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Obtaining dependency information for protobuf<7,>=3.20 from https://files.pythonhosted.org/packages/8c/f3/6f58f841f6ebafe076cebeae33fc336e900619d34b1c93e4b5c97a81fdfa/protobuf-6.32.1-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (2.1.6)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/01/61/d4b89fec821f72385526e1b9d9a3a0385dda4a72b206d28049e2c7cd39b8/gitpython-3.1.45-py3-none-any.whl.metadata
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Obtaining dependency information for pydeck<1,>=0.8.0b4 from https://files.pythonhosted.org/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\programdata\anaconda31\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda31\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda31\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda31\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: xyzservices in c:\programdata\anaconda31\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda31\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda31\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda31\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda31\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda31\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda31\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.17.3)
# Collecting narwhals>=1.14.2 (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit)
#   Obtaining dependency information for narwhals>=1.14.2 from https://files.pythonhosted.org/packages/f8/5a/22741c5c0e5f6e8050242bfc2052ba68bc94b1735ed5bca35404d136d6ec/narwhals-2.5.0-py3-none-any.whl.metadata
#   Downloading narwhals-2.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda31\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda31\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi in c:\users\asus\appdata\roaming\python\python311\site-packages (from pyogrio>=0.7.2->geopandas) (2025.8.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda31\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda31\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda31\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl.metadata
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda31\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.18.0)
# Downloading streamlit-1.49.1-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.4/10.0 MB 7.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/10.0 MB 6.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/10.0 MB 6.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/10.0 MB 6.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.5/10.0 MB 6.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.9/10.0 MB 6.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.3/10.0 MB 7.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.8/10.0 MB 7.5 MB/s eta 0:00:01
#    ------------ --------------------------- 3.2/10.0 MB 7.5 MB/s eta 0:00:01
#    -------------- ------------------------- 3.6/10.0 MB 7.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.9/10.0 MB 7.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.3/10.0 MB 7.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.7/10.0 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 5.1/10.0 MB 7.9 MB/s eta 0:00:01
#    --------------------- ------------------ 5.5/10.0 MB 7.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/10.0 MB 7.8 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/10.0 MB 7.9 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/10.0 MB 7.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.0/10.0 MB 7.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.4/10.0 MB 7.9 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/10.0 MB 8.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.2/10.0 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.6/10.0 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/10.0 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.0 MB 8.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 7.8 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ------------------ --------------------- 337.9/731.2 kB 7.0 MB/s eta 0:00:01
#    ------------------------------------ --- 675.8/731.2 kB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 731.2/731.2 kB 5.8 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.0-py3-none-any.whl (11 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
#    ---------------------------------------- 0.0/208.2 kB ? eta -:--:--
#    ---------------------------------------- 208.2/208.2 kB 6.4 MB/s eta 0:00:00
# Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl (435 kB)
#    ---------------------------------------- 0.0/435.7 kB ? eta -:--:--
#    ------------------------ --------------- 266.2/435.7 kB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 435.7/435.7 kB 6.8 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB 10.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.7/6.9 MB 9.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.1/6.9 MB 8.5 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/6.9 MB 8.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.8/6.9 MB 8.4 MB/s eta 0:00:01
#    ------------ --------------------------- 2.2/6.9 MB 8.1 MB/s eta 0:00:01
#    -------------- ------------------------- 2.5/6.9 MB 7.9 MB/s eta 0:00:01
#    --------------- ------------------------ 2.8/6.9 MB 7.6 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.9 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 3.5/6.9 MB 7.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.9 MB 7.8 MB/s eta 0:00:01
#    ------------------------- -------------- 4.3/6.9 MB 7.9 MB/s eta 0:00:01
#    --------------------------- ------------ 4.7/6.9 MB 7.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.1/6.9 MB 8.0 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/6.9 MB 8.0 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.9 MB 8.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.1/6.9 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------- -- 6.5/6.9 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  6.9/6.9 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 7.4 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# Downloading narwhals-2.5.0-py3-none-any.whl (407 kB)
#    ---------------------------------------- 0.0/407.3 kB ? eta -:--:--
#    ------------------------------ --------- 307.2/407.3 kB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 407.3/407.3 kB 8.4 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, protobuf, narwhals, cachetools, blinker, pydeck, gitdb, altair, gitpython, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-6.2.0 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.5.0 protobuf-6.32.1 pydeck-0.9.1 smmap-5.0.2 streamlit-1.49.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script streamlit.exe is installed in 'C:\Users\ASUS\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import streamlit as st
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
import numpy as np
import os
import streamlit.components.v1 as components
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

# =============================================================================
## CONFIGURACIÓN INICIAL DE STREAMLIT
# =============================================================================

st.set_page_config(
    page_title="Hospitales en Perú - Análisis Geoespacial", 
    layout="wide", 
    page_icon="🏥"
)

st.title("🏥 Análisis Geoespacial de Hospitales en Perú")
st.markdown("**Análisis de accesibilidad y distribución de hospitales públicos operacionales**")

# =============================================================================
## CONFIGURACIÓN DE RUTAS
# =============================================================================

INPUT_PATH = r"C:\Users\ASUS\OneDrive - Universidad del Pacífico\Tareas Data Science\Hospitals-Access-Peru\Input"
OUTPUT_PATH = r"C:\Users\ASUS\OneDrive - Universidad del Pacífico\Tareas Data Science\Hospitals-Access-Peru\Output"

# =============================================================================
## FUNCIONES AUXILIARES
# =============================================================================

def load_csv_safe(file_path):
    """Carga CSV de forma segura con diferentes encodings"""
    if not os.path.exists(file_path):
        return None
    
    for encoding in ['utf-8', 'latin-1', 'cp1252']:
        try:
            return pd.read_csv(file_path, encoding=encoding)
        except:
            continue
    return None

def load_html_file(file_path):
    """Carga archivo HTML si existe"""
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as f:
            return f.read()
    return None

def show_image_safe(image_path, caption="", width=None):
    """Muestra imagen si existe"""
    if os.path.exists(image_path):
        if width:
            st.image(image_path, caption=caption, width=width)
        else:
            st.image(image_path, caption=caption, use_column_width=True)
    else:
        st.warning(f"⚠️ Imagen no encontrada: {os.path.basename(image_path)}")

# =============================================================================
## CARGAR DATOS BÁSICOS
# =============================================================================

## Cargar datos principales si existen
csv_path = os.path.join(OUTPUT_PATH, "hospitales_procesados.csv")
hospitals_df = load_csv_safe(csv_path)

dept_summary_path = os.path.join(OUTPUT_PATH, "resumen_departamentos.csv")
dept_summary = load_csv_safe(dept_summary_path)

# =============================================================================
## CREACIÓN DE PESTAÑAS
# =============================================================================

tab1, tab2, tab3 = st.tabs(["🗂️ Data Description", "🗺️ Static Maps", "🌍 Dynamic Maps"])

# =============================================================================
## TAB 1: DESCRIPCIÓN DE DATOS
# =============================================================================

with tab1:
    st.header("🗂️ Descripción de los Datos")
    
    ## Métricas principales
    if hospitals_df is not None:
        col1, col2, col3, col4 = st.columns(4)
        
        with col1:
            st.metric("🏥 Total de Hospitales", f"{len(hospitals_df):,}")
        
        with col2:
            dept_count = hospitals_df['Departamento'].nunique() if 'Departamento' in hospitals_df.columns else 0
            st.metric("🗺️ Departamentos", f"{dept_count}")
        
        with col3:
            dist_count = hospitals_df['Distrito'].nunique() if 'Distrito' in hospitals_df.columns else 0
            st.metric("📍 Distritos", f"{dist_count}")
        
        with col4:
            st.metric("✅ Análisis", "Completo")
    
    else:
        st.warning("⚠️ No se encontraron datos procesados. Ejecuta primero el análisis principal.")
    
    st.markdown("---")
    
    ## Información metodológica
    st.subheader("📊 Metodología del Análisis")
    
    col1, col2 = st.columns(2)
    
    with col1:
        st.markdown("""
        **🎯 Unidad de Análisis:**
        - Hospitales públicos operacionales en Perú
        - Solo establecimientos con condición "EN FUNCIONAMIENTO"
        - Excluye establecimientos privados
        - Solo hospitales generales y especializados
        
        **📐 Sistema de Coordenadas:**
        - Análisis: EPSG:4326 (WGS84)
        - Rango válido Perú: Lat [-18.5, 0], Lon [-81.5, -68.5]
        """)
    
    with col2:
        st.markdown("""
        **📋 Fuentes de Datos:**
        - 🏥 **MINSA - IPRESS**: Registro Nacional de Establecimientos
        - 🗺️ **IGN**: Límites administrativos (distritos)
        - 📍 **INEI**: Centros poblados para análisis de proximidad
        
        **🔧 Herramientas Utilizadas:**
        - GeoPandas para análisis geoespacial
        - Folium para mapas interactivos
        - Matplotlib para visualizaciones estáticas
        """)
    
    st.markdown("---")
    
    ## Tabla de datos si existe
    if hospitals_df is not None:
        st.subheader("📋 Muestra de Datos Procesados")
        
        display_columns = ['Nombre del establecimiento', 'Departamento', 'Provincia', 
                          'Distrito', 'Clasificación', 'lat', 'lon']
        
        available_columns = [col for col in display_columns if col in hospitals_df.columns]
        
        if available_columns:
            st.dataframe(
                hospitals_df[available_columns].head(20), 
                width=1200,
                height=400
            )
    
    ## Distribución por departamento
    if dept_summary is not None:
        st.subheader("📈 Distribución por Departamento")
        
        col1, col2 = st.columns([2, 1])
        
        with col1:
            fig, ax = plt.subplots(figsize=(10, 6))
            dept_data = dept_summary.head(10) if 'Num_Hospitales' in dept_summary.columns else dept_summary.head(10)
            
            if 'Num_Hospitales' in dept_summary.columns:
                dept_data.plot(x=dept_summary.index, y='Num_Hospitales', kind='bar', ax=ax, color='skyblue', edgecolor='navy')
            else:
                dept_summary.head(10).plot(kind='bar', ax=ax, color='skyblue', edgecolor='navy')
            
            ax.set_title('Top 10 Departamentos con Más Hospitales', fontsize=12, fontweight='bold')
            ax.set_xlabel('Departamento')
            ax.set_ylabel('Número de Hospitales')
            ax.tick_params(axis='x', rotation=45)
            plt.tight_layout()
            st.pyplot(fig)
        
        with col2:
            st.markdown("**📊 Estadísticas:**")
            if 'Num_Hospitales' in dept_summary.columns:
                max_val = dept_summary['Num_Hospitales'].max()
                min_val = dept_summary['Num_Hospitales'].min()
                avg_val = dept_summary['Num_Hospitales'].mean()
                st.write(f"• **Máximo:** {max_val} hospitales")
                st.write(f"• **Mínimo:** {min_val} hospitales")
                st.write(f"• **Promedio:** {avg_val:.1f} hospitales")
            else:
                st.write("• Ver tabla para estadísticas detalladas")

# =============================================================================
## TAB 2: MAPAS ESTÁTICOS
# =============================================================================

with tab2:
    st.header("🗺️ Mapas Estáticos & Análisis por Departamento")
    
    ## MAPAS ESTÁTICOS GENERADOS
    st.subheader("🗺️ Mapas Estáticos Generados")
    
    ## Mapa 1: Total hospitales por distrito
    st.markdown("### 📍 Mapa 1: Total de Hospitales por Distrito")
    map1_path = os.path.join(OUTPUT_PATH, "mapa1_hospitales_distrito.png")
    show_image_safe(map1_path, "Distribución del número de hospitales por distrito")
    
    ## Mapa 2: Distritos sin hospitales
    st.markdown("### 🚫 Mapa 2: Distritos Sin Hospitales")
    map2_path = os.path.join(OUTPUT_PATH, "mapa2_distritos_sin_hospitales.png")
    show_image_safe(map2_path, "Distritos sin acceso a hospitales públicos")
    
    ## Mapa 3: Top 10 distritos
    st.markdown("### 🏆 Mapa 3: Top 10 Distritos con Más Hospitales")
    map3_path = os.path.join(OUTPUT_PATH, "mapa3_top10_distritos.png")
    show_image_safe(map3_path, "Distritos con mayor concentración hospitalaria")
    
    st.markdown("---")
    
    ## ANÁLISIS DEPARTAMENTAL
    st.subheader("🏛️ Análisis Departamental Completo")
    
    col1, col2 = st.columns(2)
    
    with col1:
        st.markdown("#### 📋 Tabla Resumen Departamental")
        if dept_summary is not None:
            st.dataframe(dept_summary, width=600)
            
            ## Descargar CSV
            csv = dept_summary.to_csv()
            st.download_button(
                label="📥 Descargar Tabla (CSV)",
                data=csv,
                file_name="resumen_departamentos.csv",
                mime="text/csv"
            )
        else:
            st.warning("⚠️ No se encontró tabla resumen departamental")
    
    with col2:
        st.markdown("#### 📊 Gráfico de Barras Departamental")
        graph_path = os.path.join(OUTPUT_PATH, "grafico_departamentos.png")
        if os.path.exists(graph_path):
            show_image_safe(graph_path, "Hospitales por departamento")
        else:
            ## Generar gráfico básico si existe dept_summary
            if dept_summary is not None:
                fig, ax = plt.subplots(figsize=(8, 10))
                if 'Num_Hospitales' in dept_summary.columns:
                    dept_summary['Num_Hospitales'].plot(kind='barh', ax=ax, color='coral', edgecolor='darkred')
                else:
                    dept_summary.iloc[:, 0].plot(kind='barh', ax=ax, color='coral', edgecolor='darkred')
                ax.set_title('Hospitales por Departamento', fontsize=12, fontweight='bold')
                ax.set_xlabel('Número de Hospitales')
                ax.grid(axis='x', alpha=0.3)
                plt.tight_layout()
                st.pyplot(fig)

# =============================================================================
## TAB 3: MAPAS DINÁMICOS
# =============================================================================

with tab3:
    st.header("🌍 Mapas Dinámicos Interactivos")
    
    ## MAPA NACIONAL COROPLÉTICO
    st.subheader("🗺️ Mapa Nacional Interactivo")
    
    national_map_path = os.path.join(OUTPUT_PATH, "mapa_nacional_coropletico.html")
    national_html = load_html_file(national_map_path)
    
    if national_html:
        st.markdown("**Mapa nacional con coropleta de densidad + clusters de hospitales por departamento**")
        components.html(national_html, height=600, scrolling=False)
    else:
        st.warning("⚠️ No se encontró el mapa nacional. Ejecuta el análisis principal primero.")
        st.info("Archivo esperado: mapa_nacional_coropletico.html")
    
    st.markdown("---")
    
    ## ANÁLISIS DE PROXIMIDAD LIMA Y LORETO
    st.subheader("📍 Análisis de Proximidad: Lima vs Loreto")
    st.markdown("**Análisis de accesibilidad hospitalaria con buffers de 10km**")
    
    col1, col2 = st.columns(2)
    
    ## PROXIMIDAD LIMA
    with col1:
        st.markdown("#### 🏙️ Lima - Concentración Urbana")
        
        lima_map_path = os.path.join(OUTPUT_PATH, "mapa_proximidad_lima.html")
        lima_html = load_html_file(lima_map_path)
        
        if lima_html:
            components.html(lima_html, height=500, scrolling=False)
            st.info("**Lima:** Alta concentración urbana mejora accesibilidad en el centro metropolitano.")
        else:
            st.warning("⚠️ No se encontró el mapa de proximidad de Lima")
            st.info("Archivo esperado: mapa_proximidad_lima.html")
    
    ## PROXIMIDAD LORETO
    with col2:
        st.markdown("#### 🌳 Loreto - Dispersión Geográfica")
        
        loreto_map_path = os.path.join(OUTPUT_PATH, "mapa_proximidad_loreto.html")
        loreto_html = load_html_file(loreto_map_path)
        
        if loreto_html:
            components.html(loreto_html, height=500, scrolling=False)
            st.info("**Loreto:** Dispersión geográfica y barreras naturales limitan accesibilidad.")
        else:
            st.warning("⚠️ No se encontró el mapa de proximidad de Loreto")
            st.info("Archivo esperado: mapa_proximidad_loreto.html")
    
    ## ANÁLISIS ESCRITO FINAL
    st.markdown("---")
    st.subheader("📝 Análisis Comparativo Final")
    
    col1, col2 = st.columns(2)
    
    with col1:
        st.markdown("""
        **🏙️ Lima - Concentración Urbana:**
        - **Ventaja:** Alta densidad hospitalaria en área metropolitana
        - **Accesibilidad:** Múltiples hospitales dentro de 10km en zonas céntricas
        - **Transporte:** Red vial desarrollada facilita acceso
        - **Desafío:** Posible saturación de servicios en centro vs. periferia
        """)
    
    with col2:
        st.markdown("""
        **🌳 Loreto - Dispersión Amazónica:**
        - **Desafío:** Grandes distancias entre establecimientos
        - **Geografía:** Ríos como principales vías de transporte
        - **Accesibilidad:** Pocos hospitales por área, acceso limitado
        - **Oportunidad:** Telemedicina y unidades móviles como alternativas
        """)
    
    ## Archivos adicionales disponibles
    st.markdown("---")
    st.subheader("📁 Archivos de Análisis Disponibles")
    
    ## Listar archivos en OUTPUT_PATH
    if os.path.exists(OUTPUT_PATH):
        files = os.listdir(OUTPUT_PATH)
        
        col1, col2, col3 = st.columns(3)
        
        with col1:
            st.markdown("**🗺️ Mapas Estáticos:**")
            for file in files:
                if file.endswith('.png'):
                    st.text(f"• {file}")
        
        with col2:
            st.markdown("**🌍 Mapas Interactivos:**")
            for file in files:
                if file.endswith('.html'):
                    st.text(f"• {file}")
        
        with col3:
            st.markdown("**📊 Datos y Reportes:**")
            for file in files:
                if file.endswith('.csv') or file.endswith('.txt'):
                    st.text(f"• {file}")

## INFORMACIÓN TÉCNICA ADICIONAL
st.markdown("---")
with st.expander("ℹ️ Información Técnica", expanded=False):
    st.markdown("""
    **🔧 Herramientas Utilizadas:**
    - **Streamlit:** Aplicación web interactiva
    - **GeoPandas:** Análisis geoespacial y spatial joins
    - **Folium:** Mapas interactivos con Leaflet.js
    - **Matplotlib:** Gráficos estáticos
    - **Pandas:** Procesamiento de datos

    **📊 Parámetros del Análisis:**
    - **Radio de análisis:** 10 km para buffers de proximidad
    - **Sistema de coordenadas:** EPSG:4326 (WGS84)
    - **Filtros aplicados:** Solo hospitales públicos operacionales
    - **Rango geográfico:** Territorio peruano [-18.5°, 0°] lat, [-81.5°, -68.5°] lon

    **📝 Metodología:**
    1. Carga y filtrado de datos IPRESS
    2. Corrección automática de coordenadas
    3. Spatial joins para análisis por distrito
    4. Cálculo de centroides para análisis de proximidad
    5. Visualización con mapas estáticos e interactivos
    
    **📂 Ubicaciones de Archivos:**
    - **Input:** Datos originales IPRESS.csv y shapefiles
    - **Output:** Mapas, gráficos y análisis generados
    """)

# =============================================================================
## PIE DE PÁGINA
# =============================================================================

st.markdown("---")
st.markdown("""
<div style='text-align: center; color: gray;'>
<small>
📊 Análisis Geoespacial de Hospitales en Perú | 
Curso: Data Science con Python | 
Universidad del Pacífico 2025
</small>
</div>
""", unsafe_allow_html=True)
# Out:
# 2025-09-20 22:06:39.142 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.143 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.936
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-09-20 22:06:39.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:39.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:40.603 The `use_column_width` parameter has been deprecated and will be removed in a future release. Please utilize the `use_container_width` parameter instead.
# 2025-09-20 22:06:40.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.038 The `use_column_width` parameter has been deprecated and will be removed in a future release. Please utilize the `use_container_width` parameter instead.
# 2025-09-20 22:06:41.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.394 The `use_column_width` parameter has been deprecated and will be removed in a future release. Please utilize the `use_container_width` parameter instead.
# 2025-09-20 22:06:41.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:41.965 The `use_column_width` parameter has been deprecated and will be removed in a future release. Please utilize the `use_container_width` parameter instead.
# 2025-09-20 22:06:41.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:42.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-20 22:06:43.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
streamlit run C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py
# Out:
#   Cell In[3], line 1
#     streamlit run C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py
#               ^
# SyntaxError: invalid syntax
